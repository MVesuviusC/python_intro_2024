# %% [markdown]
# # Learning python - Day 4
#
# ## Background :
#
# - Plotting
#     - Several powerful Python plotting packages, incl. [plotly](https://plotly.com/python/), [matplotlib](https://matplotlib.org/) and [seaborn](https://seaborn.pydata.org/)
# - Matplotlib
#     - [Two interfaces](https://matplotlib.org/stable/users/explain/figure/api_interfaces.html) for Matplotlib
#         - Object oriented :
#             * Explicit "Axes" interface that uses methods on a Figure or Axes object
#         - Pyplot :
#             * An implicit "pyplot" interface that keeps track of the last Figure and Axes created
#     - BIGGEST source of confusion

# %% [markdown]
# ## Simple Plots

# %% [markdown]
# ### Pyplot Inteface

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])
#plt.show()         # Needed if plotting outside of VS Code

# %% [markdown]
# #### Add labels to above pyplot example

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])
plt.xlabel('cool variable')
plt.ylabel('Even cooler response')
plt.title("My interesting experiment")
# help(plt)  Note - that plt.xlabel() modifies it in place vs pandas
# Out:
# Text(0.5, 1.0, 'My interesting experiment')

# %% [markdown]
# ### Object-Oriented Interface

# %%
import matplotlib.pyplot as plt
# Think of this like building layers a la ggplot() in R
fig = plt.figure()
ax = fig.subplots()
ax.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])

# %% [markdown]
# ### Object Oriented Interface
#
#
# <img src="anatomy_of_a_figure_matplotlib.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# #### Let's now try improving simple plot

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.subplots()
ax.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2], label="bad data")
ax.set_xlabel("My cool variable")
ax.set_ylabel("My scary response")
ax.legend(loc='lower right', fontsize=10)

# %% [markdown]
# #### Add a second set of data

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = [1, 2, 3, 4]
y1 = [0, 0.5, 1, 0.2]
y2 = np.random.random(4) * 10   ## Gets 4 rand nums, scale by 10

# Plot
fig = plt.figure()
ax = fig.subplots()
# Note we by ax(es) is a sub set of the overall fig(ure), you're modifying 'part' of the 'fig'
ax.plot(x, y1, label="bad data", color="blue")
ax.plot(x, y2, label="random data", color="red")

ax.set_xlabel("My cool variable")
ax.set_ylabel("My scary response")
ax.legend(loc='lower right', fontsize=10)
ax.set_title("My terrible plot")
# Out:
# Text(0.5, 1.0, 'My terrible plot')

# %% [markdown]
# #### Exercise 1 :
# - Take above code and make a scatter plot instead.  Hint : use ax.scatter()

# %%
## Enter code here for Exercise 1

# %% [markdown]
# #### Create two plots side-by-side

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = [1, 2, 3, 4]
y1 = [0, 0.5, 1, 0.2]
y2 = np.random.random(4) * 10   ## Gets 4 rand nums, scale by 10

# Plot
fig = plt.figure()
gs = fig.add_gridspec(1,2)    # args = nrow,ncol; Use for multiple sub plots
# Left Plot
ax = fig.add_subplot(gs[0,0])
ax.plot(x, y1, label="bad data", color="blue")
ax.set_xlabel("My cool variable")
ax.set_ylabel("My blue response")
ax.legend(loc='lower right', fontsize=10)
ax.set_title("My Blue plot")

# Right Plot
ax = fig.add_subplot(gs[0,1])
ax.plot(x, y2, label="random data", color="red")
ax.set_xlabel("My cool variable")
ax.set_ylabel("My Red response")
ax.legend(loc='upper right', fontsize=10)
ax.set_title("My Red plot")
fig.suptitle("The great blue/red debate", fontsize=16)

# Can adjust white space between plots with fig.subplots_adjust() and fig.tight_layout()
fig.subplots_adjust(wspace=0.25,hspace=1)
#fig.tight_layout()

# %% [markdown]
# #### Exercise 2 : Create a plot with 4 sub-panels, use above code as a template

# %%
### Exercise 2 code here

# %% [markdown]
# #### Heat map

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import data -
#   --> CC BY-SA 4.0 : https://archive.ics.uci.edu/dataset/109/wine
#   --> Aeberhard,Stefan and Forina,M.. (1991). Wine. UCI Machine Learning Repository. https://doi.org/10.24432/C5PC7J.
df = pd.read_csv("data/wine.data")       # No headers...
# Got headers from data/wine.names
header=["cult", "alcohol", "malic", "ash", "alcalinity", "mg", "phenol", "flav",
        "nonflav","proanth", "color", "hue", "od280", "proline"]
df.columns = header
cult1 = df[df['cult'] == 1].iloc[0:4]  # *.iloc for indices, *.loc for row names
cult2 = df[df['cult'] == 2].iloc[0:4]
cult3 = df[df['cult'] == 3].iloc[0:4]
allcult = [cult1, cult2, cult3]
cultname=['1','2','3']

# Create matrix for plotting
m = np.zeros([3, cult1.shape[0]])  # 3 cultivars, 5 wines per cultivar
# cultivars first
for i in range(len(allcult)):
    # wines next
    for j in range(allcult[i].shape[0]):
        m[i,j] = allcult[i]['alcohol'].iloc[j]

# Plot
fig, ax = plt.subplots()
im = ax.imshow(m)
# y-axis
ax.set_yticks(np.arange(len(cultname)))
ax.set_yticklabels(cultname)
ax.set_ylabel("Cultivar")
# x-axis
ax.set_xticks(np.arange(m.shape[1]))
#ax.set_xticklabels(cultname)
ax.set_xlabel("Wine")
ax.legend(loc='lower right', fontsize=10)
ax.set_title("Alcohol content of 3 cultivars")
plt.show()      # Needed if plotting python outside of Jupyter notebook
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Exercise 3 : Create a with a colorbar, use above code as a template.
# - Hint : https://matplotlib.org/stable/gallery/color/colorbar_basics.html

# %%
### Exercise 3 code here

# %% [markdown]
# #### Exercise 4 : Customize the above plot by changing default colors to go from red -> purple
# - Hints :
#     * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html
#     * https://matplotlib.org/3.3.4/gallery/color/colormap_reference.html

# %%
### Exercise 4 code here
